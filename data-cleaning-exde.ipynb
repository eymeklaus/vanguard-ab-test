# %% [markdown]
# # DATA EXPLORATION - VANGUARD A/B TEST
# ---

# %% [markdown]
# **Question was: Would these changes encourage more clients to complete the process?**
# Database Client Profiles (df_final_demo): Demographics like age, gender, and account details of our clients.
# Experiment Roster (df_final_experiment_clients): A list revealing which clients were part of the grand experiment.

# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_style("whitegrid")

# %% [markdown]
# 1. LOAD THE DATASETS

# %%
data_path = "data/raw_data"
df_demo = pd.read_csv(f"{data_path}/df_final_demo.txt")
df_experiment = pd.read_csv(f"{data_path}/df_final_experiment_clients.txt")

# %% [markdown]
# ## Phase 1 — EDA & Data Cleaning

# %% [markdown]
# DATASET: DEMOGRAPHICS

# %%
df_demo.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976            6.00             73.00     60.50     U       2.00
# 1    2304905            7.00             94.00     58.00     U       2.00
# 2    1439522            5.00             64.00     32.00     U       2.00
# 3    1562045           16.00            198.00     49.00     M       2.00
# 4    5126305           12.00            145.00     33.00     F       2.00
#
#         bal  calls_6_mnth  logons_6_mnth
# 0  45105.30          6.00           9.00
# 1 110860.30          6.00           9.00
# 2  52467.79          6.00           9.00
# 3  67454.65          3.00           6.00
# 4 103671.75          0.00           3.00

# %%
df_demo.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                object
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
df_demo.shape
# Out:
# (70609, 9)

# %% [markdown]
# DATASET: EXPERIMENT ROSTER

# %%
df_experiment.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_experiment.shape
# Out:
# (70609, 2)

# %%
# merging both databases

df_exde = pd.merge(df_demo, df_experiment, on='client_id', how='outer')
df_exde
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0            169           21.00            262.00     47.50     M       2.00
# 1            555            3.00             46.00     29.50     U       2.00
# 2            647           12.00            151.00     57.50     M       2.00
# 3            722           11.00            143.00     59.50     F       2.00
# 4            934            9.00            109.00     51.00     F       2.00
# ...          ...             ...               ...       ...   ...        ...
# 70604    9999400            7.00             86.00     28.50     U       2.00
# 70605    9999626            9.00            113.00     35.00     M       2.00
# 70606    9999729           10.00            124.00     31.00     F       3.00
# 70607    9999832           23.00            281.00     49.00     F       2.00
# 70608    9999839           13.00            160.00     28.50     F       2.00
#
#             bal  calls_6_mnth  logons_6_mnth Variation
# 0     501570.72          4.00           4.00       NaN
# 1      25454.66          2.00           6.00      Test
# 2      30525.80          0.00           4.00      Test
# 3      22466.17          1.00           1.00       NaN
# 4      32522.88          0.00           3.00      Test
# ...         ...           ...            ...       ...
# 70604  51787.04          0.00           3.00      Test
# 70605  36642.88          6.00           9.00      Test
# 70606 107059.74          6.00           9.00      Test
# 70607 431887.61          1.00           4.00      Test
# 70608  67425.35          3.00           3.00       NaN
#
# [70609 rows x 10 columns]

# %% [markdown]
# **Rename Columns**

# %%
#renaming columns
df_exde.columns = df_exde.columns.str.lower().str.replace(' ', '_')
df_exde.rename(columns= {'gendr': 'gender', "bal": 'balance'}, inplace=True)

# %%
df_exde.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gender  num_accts  \
# 0        169           21.00            262.00     47.50      M       2.00
# 1        555            3.00             46.00     29.50      U       2.00
# 2        647           12.00            151.00     57.50      M       2.00
# 3        722           11.00            143.00     59.50      F       2.00
# 4        934            9.00            109.00     51.00      F       2.00
#
#     balance  calls_6_mnth  logons_6_mnth variation
# 0 501570.72          4.00           4.00       NaN
# 1  25454.66          2.00           6.00      Test
# 2  30525.80          0.00           4.00      Test
# 3  22466.17          1.00           1.00       NaN
# 4  32522.88          0.00           3.00      Test

# %%
df_exde.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gender               object
# num_accts           float64
# balance             float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# variation            object
# dtype: object

# %% [markdown]
# ## Dealing with NULL VALUES

# %%
# finding nulls
df_exde.isna().sum()
# Out:
# client_id               0
# clnt_tenure_yr         14
# clnt_tenure_mnth       14
# clnt_age               15
# gender                 14
# num_accts              14
# balance                14
# calls_6_mnth           14
# logons_6_mnth          14
# variation           20109
# dtype: int64

# %%
df_exde.dropna(subset=['variation'], inplace=True)

# %%
# finding nulls
df_exde.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      12
# clnt_tenure_mnth    12
# clnt_age            13
# gender              12
# num_accts           12
# balance             12
# calls_6_mnth        12
# logons_6_mnth       12
# variation            0
# dtype: int64

# %% [markdown]
# **Standarizing Data**

# %%
num_cols = df_exde.select_dtypes(include='number').columns

df_exde[num_cols] = df_exde[num_cols].fillna(df_exde[num_cols].median())

# %%
df_exde["gender"].value_counts()
# Out:
# gender
# U    17280
# M    16947
# F    16259
# X        2
# Name: count, dtype: int64

# %%
# formating a column with a function
def clean_sex_column(x):
    if pd.isna(x):
        return "unknown"
    if x in ["F"]:
        return "female"
    elif x in ["M"]:
        return "male"
    elif x in ["U", "X"]:
        return "unknown"
    else:
        return "unknown"

# %%
df_exde['gender'] = df_exde['gender'].apply(clean_sex_column)

# %%
# finding nulls
df_exde.isna().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gender              0
# num_accts           0
# balance             0
# calls_6_mnth        0
# logons_6_mnth       0
# variation           0
# dtype: int64

# %%
def age_group(x):
    if x < 30:
        return "young"
    elif 30 <= x <= 60:
        return "adult"
    else:
        return "senior"

# %%
df_exde["age_group"] = df_exde["clnt_age"].apply(age_group)

# %%
# duplicates sum
df_exde.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_exde.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age   gender  num_accts  \
# 1        555            3.00             46.00     29.50  unknown       2.00
# 2        647           12.00            151.00     57.50     male       2.00
# 4        934            9.00            109.00     51.00   female       2.00
# 5       1028           12.00            145.00     36.00     male       3.00
# 6       1104            5.00             66.00     48.00  unknown       3.00
#
#     balance  calls_6_mnth  logons_6_mnth variation age_group
# 1  25454.66          2.00           6.00      Test     young
# 2  30525.80          0.00           4.00      Test     adult
# 4  32522.88          0.00           3.00      Test     adult
# 5 103520.22          1.00           4.00   Control     adult
# 6 154643.94          6.00           9.00   Control     adult

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# **Categorical Variables**

# %%
# descriptive analysis categorical variables 
df_exde["variation"].value_counts()
# Out:
# variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_exde["gender"].value_counts()
# Out:
# gender
# unknown    17294
# male       16947
# female     16259
# Name: count, dtype: int64

# %%
df_exde["age_group"].value_counts()
# Out:
# age_group
# adult     29934
# senior    12035
# young      8531
# Name: count, dtype: int64

# %%
pd.crosstab(df_exde['variation'], df_exde["gender"] )
# Out:
# gender     female  male  unknown
# variation
# Control      7543  7970     8019
# Test         8716  8977     9275

# %%
pd.crosstab(df_exde['variation'], df_exde["gender"], normalize='index')
# Out:
# gender     female  male  unknown
# variation
# Control      0.32  0.34     0.34
# Test         0.32  0.33     0.34

# %%
pd.crosstab(df_exde['variation'], df_exde["age_group"])
# Out:
# age_group  adult  senior  young
# variation
# Control    13928    5669   3935
# Test       16006    6366   4596

# %%
pd.crosstab(df_exde['variation'], df_exde["age_group"], normalize='index')
# Out:
# age_group  adult  senior  young
# variation
# Control     0.59    0.24   0.17
# Test        0.59    0.24   0.17

# %% [markdown]
# ## Numerical Variables

# %%
# descriptive analysis numerical variables
pd.set_option('display.float_format', '{:.2f}'.format)
df_exde.describe()
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count   50500.00        50500.00          50500.00  50500.00   50500.00
# mean  5006179.06           12.03            150.41     47.32       2.25
# std   2877442.53            6.86             81.94     15.52       0.53
# min       555.00            2.00             33.00     17.00       1.00
# 25%   2515645.75            6.00             82.00     33.50       2.00
# 50%   5025103.50           11.00            136.00     48.00       2.00
# 75%   7477933.25           16.00            192.00     59.50       2.00
# max   9999832.00           55.00            669.00     96.00       7.00
#
#           balance  calls_6_mnth  logons_6_mnth
# count    50500.00      50500.00       50500.00
# mean    149494.77          3.09           6.13
# std     302003.29          2.19           2.18
# min      23789.44          0.00           3.00
# 25%      39881.04          1.00           4.00
# 50%      65733.60          3.00           6.00
# 75%     139938.95          5.00           8.00
# max   16320040.15          6.00           9.00

# %%
df_exde.groupby('variation')['clnt_tenure_yr'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count  mean  std   max  min
# 0   Control  23532 12.09 6.88 55.00 2.00
# 1      Test  26968 11.98 6.84 55.00 2.00

# %%
df_exde.groupby('variation')['clnt_age'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count  mean   std   max   min
# 0   Control  23532 47.50 15.52 96.00 17.00
# 1      Test  26968 47.16 15.51 96.00 17.00

# %%
df_exde.groupby('variation')['num_accts'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count  mean  std  max  min
# 0   Control  23532  2.26 0.54 7.00 2.00
# 1      Test  26968  2.25 0.53 7.00 1.00

# %%
df_exde.groupby('variation')['balance'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count      mean       std         max      min
# 0   Control  23532 150129.39 295778.08  8292996.21 23789.61
# 1      Test  26968 148941.00 307336.74 16320040.15 23789.44

# %%
df_exde.groupby('variation')['calls_6_mnth'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count  mean  std  max  min
# 0   Control  23532  3.13 2.18 6.00 0.00
# 1      Test  26968  3.06 2.19 6.00 0.00

# %%
df_exde.groupby('variation')['logons_6_mnth'].agg(['count', 'mean','std','max', 'min']).reset_index()
# Out:
#   variation  count  mean  std  max  min
# 0   Control  23532  6.17 2.17 9.00 3.00
# 1      Test  26968  6.10 2.18 9.00 3.00

# %% [markdown]
# ## Exporting Database

# %%
# exporting database
output_dir = "data/processed"
os.makedirs(output_dir, exist_ok=True)

df_exde.to_csv(f"{output_dir}/df_exde.csv", index=False)

print("Exported:")
for f in os.listdir(output_dir):
    path = os.path.join(output_dir, f)
    size = os.path.getsize(path)
    print(f"  {f} ({size:,} bytes)")
# Out:
# Exported:
#   df_exde.csv (3,302,143 bytes)
#   df_web_3.csv (81,420,206 bytes)
#   web.csv (40,471,437 bytes)
